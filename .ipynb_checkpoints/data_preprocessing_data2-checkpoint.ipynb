# %%
import pandas as pd
import math
import re
import matplotlib.pyplot as plt

# %%
data_url = "./data/단향 측정 데이터_김소희.xlsx"
df_dict = pd.read_excel(data_url, sheet_name=None)
print(df_dict)
# Out:
# {'1-heptanol':        Timestamps (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  \
# 0              0.000007  1.455080e-07  6.162300e-08  6.162300e-08
# 1              1.089014  1.512110e-07  6.103500e-08  6.103500e-08
# 2              2.241256  1.524380e-07  6.136400e-08  6.136400e-08
# 3              3.319816  1.522550e-07  6.101100e-08  6.101100e-08
# 4              4.403149  1.519720e-07  6.050100e-08  6.050100e-08
# ...                 ...           ...           ...           ...
# 35752      42317.146907  1.355400e-07  1.547080e-06  1.547080e-06
# 35753      42318.359245  1.370170e-07  1.543610e-06  1.543610e-06
# 35754      42319.545124  1.374300e-07  1.543960e-06  1.543960e-06
# 35755      42320.737173  1.371530e-07  1.544110e-06  1.544110e-06
# 35756      42321.878927  1.372520e-07  1.534830e-06  1.534830e-06
#
#        Ids (A)_PMMA  Unnamed: 5  gas injection time switch
# 0      3.536190e-07         NaN                 0.0    off
# ...

# %%
df_dict.keys()
# Out:
# dict_keys(['1-heptanol', '1-heptanol_2', '2-ethylfenchol', '2-ethylfenchol_2', 'decanal', 'decanal_2', 'decanal_3', 'eugenol', 'eugenol_2', 'octanal', 'octanal_2', 'cis-3-hexenol', 'cis-3-hexenol_2', '2,3,5, trimethyl pyrazine', '2,3,5, trimethyl pyrazine_2', 'geraniol', 'geraniol_2'])

# %% [markdown]
# ## Things to beaware of the data
# 1. the number of rows in each sensor aren't same(Even in the same scent!)

# %%
scent_save = pd.DataFrame()

for scent_name in df_dict.keys():
    scent_data = df_dict[scent_name]
    options = scent_data.iloc[:, 6:8]
    options = options[options['gas injection time'].notnull()]
    scent_data = scent_data.iloc[:, :5]
    scent_data["scent_name"] = scent_name
    # making trials!!
    # we don't need 0!
    nose_open_close_pattern = list(options["gas injection time"])[1:] + [math.inf]
    scent_data["trial_num"] = 0
    print(nose_open_close_pattern)
    for i in range(len(nose_open_close_pattern)//2):
        scent_data["trial_num"] = scent_data.apply(lambda x: i + 1 if (nose_open_close_pattern[2*i] <= x["Timestamps (sec)"]) & (x["Timestamps (sec)"] < nose_open_close_pattern[2*i + 2]) else x["trial_num"] ,axis= 1)
#         print(scent_data)
    scent_save = pd.concat([scent_save, scent_data])
    print(f"scent_name: {scent_name}, scent_data: {scent_data}")
    print(f"options: {options}")
# scent_save.head()
# Out:
# [600.0, 1200.0, 11000.0, 11600.0, 14000.0, 14600.0, 17000.0, 17600.0, 21000.0, 21600.0, 24060.0, 24660.0, 27060.0, 27660.0, 30060.0, 30660.0, 33060.0, 33660.0, 36060.0, 36660.0, 39060.0, 39660.0, inf]
# scent_name: 1-heptanol, scent_data:        Timestamps (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  \
# 0              0.000007  1.455080e-07  6.162300e-08  6.162300e-08
# 1              1.089014  1.512110e-07  6.103500e-08  6.103500e-08
# 2              2.241256  1.524380e-07  6.136400e-08  6.136400e-08
# 3              3.319816  1.522550e-07  6.101100e-08  6.101100e-08
# 4              4.403149  1.519720e-07  6.050100e-08  6.050100e-08
# ...                 ...           ...           ...           ...
# 35752      42317.146907  1.355400e-07  1.547080e-06  1.547080e-06
# 35753      42318.359245  1.370170e-07  1.543610e-06  1.543610e-06
# 35754      42319.545124  1.374300e-07  1.543960e-06  1.543960e-06
# 35755      42320.737173  1.371530e-07  1.544110e-06  1.544110e-06
# ...

# %%
scent_save[(scent_save["trial_num"] == 1) & (scent_save["scent_name"] == "1-heptanol")]
# Out:
#       Timestamps (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  \
# 543         600.681525  1.506200e-07  6.080700e-08  6.080700e-08
# 544         601.758567  1.500970e-07  6.098600e-08  6.098600e-08
# 545         602.825071  1.461190e-07  6.068800e-08  6.068800e-08
# 546         603.936120  1.497220e-07  5.966700e-08  5.966700e-08
# 547         605.037679  1.514290e-07  6.177500e-08  6.177500e-08
# ...                ...           ...           ...           ...
# 9660      10994.702554  1.328650e-07  9.474500e-08  9.474500e-08
# 9661      10995.837691  1.359280e-07  9.454700e-08  9.454700e-08
# 9662      10997.103601  1.363900e-07  9.511900e-08  9.511900e-08
# 9663      10998.246119  1.344190e-07  9.487300e-08  9.487300e-08
# 9664      10999.437104  1.362870e-07  9.491700e-08  9.491700e-08
#
#       Ids (A)_PMMA  scent_name  trial_num  Ids (A)_PVA  Ids (A)_PC  \
# 543   2.239260e-07  1-heptanol          1          NaN         NaN
# ...

# %%
for scent_name in df_dict.keys():
    print(scent_name)
    print(scent_save[scent_save["scent_name"] == scent_name]["trial_num"].max())
# Out:
# 1-heptanol
# 11
# 1-heptanol_2
# 10
# 2-ethylfenchol
# 11
# 2-ethylfenchol_2
# 8
# decanal
# 11
# decanal_2
# 6
# decanal_3
# 6
# eugenol
# 10
# eugenol_2
# 6
# octanal
# 10
# octanal_2
# 6
# cis-3-hexenol
# 10
# cis-3-hexenol_2
# 6
# 2,3,5, trimethyl pyrazine
# 8
# 2,3,5, trimethyl pyrazine_2
# 6
# geraniol
# 8
# geraniol_2
# 6

# %%
scent_save.columns
# Out:
# Index(['Timestamps (sec)', 'Ids (A)_SAA', 'Ids (A)_PAS', 'Ids (A)_PVB',
#        'Ids (A)_PMMA', 'scent_name', 'trial_num', 'Ids (A)_PVA', 'Ids (A)_PC',
#        'Ids (A)_PS', 'Ids (A)_PVCA', 'Ids (A)_PC.1'],
#       dtype='object')

# %%
graph_df = scent_save.rename(columns = {"Timestamps (sec)": "Time (sec)", "Ids (A)_SAA": "SAA", "Ids (A)_PAS": "PAS", "Ids (A)_PVB": "PVB",
                                       "Ids (A)_PMMA": "PMMA", "Ids (A)_PVA": "PVA", "Ids (A)_PC": "PC", "Ids (A)_PS": "PS", "Ids (A)_PVCA": "PVCA",
                                       "Ids (A)_PC.1": "PC.1"})

# %%
graph_df = graph_df.set_index(["scent_name", "trial_num", "Time (sec)"])
graph_df
# Out:
#                                             SAA           PAS           PVB  \
# scent_name trial_num Time (sec)
# 1-heptanol 0         0.000007      1.455080e-07  6.162300e-08  6.162300e-08
#                      1.089014      1.512110e-07  6.103500e-08  6.103500e-08
#                      2.241256      1.524380e-07  6.136400e-08  6.136400e-08
#                      3.319816      1.522550e-07  6.101100e-08  6.101100e-08
#                      4.403149      1.519720e-07  6.050100e-08  6.050100e-08
# ...                                         ...           ...           ...
# geraniol_2 6         18703.985960           NaN           NaN           NaN
#                      18705.772664           NaN           NaN           NaN
#                      18707.612828           NaN           NaN           NaN
#                      18709.431189           NaN           NaN           NaN
#                      18711.251372           NaN           NaN           NaN
#
# ...

# %%
plt.rcParams["figure.figsize"] = (25,4)

# %%
graph_df.index.map(lambda x: x[0]).unique()
# Out:
# Index(['1-heptanol', '1-heptanol_2', '2-ethylfenchol', '2-ethylfenchol_2',
#        'decanal', 'decanal_2', 'decanal_3', 'eugenol', 'eugenol_2', 'octanal',
#        'octanal_2', 'cis-3-hexenol', 'cis-3-hexenol_2',
#        '2,3,5, trimethyl pyrazine', '2,3,5, trimethyl pyrazine_2', 'geraniol',
#        'geraniol_2'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 1, constrained_layout= True)
axes[0].plot(graph_df.loc[("1-heptanol_2", 10), ("PVA")])
axes[1].plot(graph_df.loc[("2-ethylfenchol", 1), ("SAA")])
# Out:
# C:\Users\ansck\anaconda3\lib\site-packages\pandas\core\indexing.py:1761: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
# C:\Users\ansck\anaconda3\lib\site-packages\pandas\core\indexing.py:1761: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)

# %%
graph_df.loc[("1-heptanol_2", 10)]
# Out:
# C:\Users\ansck\anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#               SAA  PAS  PVB  PMMA       PVA            PC            PS  \
# Time (sec)
# 27650.535660  NaN  NaN  NaN   NaN  0.000088  1.994600e-08  5.213500e-08
# 27652.315965  NaN  NaN  NaN   NaN  0.000088  1.985100e-08  5.156000e-08
# 27654.117767  NaN  NaN  NaN   NaN  0.000088  2.043400e-08  5.240800e-08
# 27655.886967  NaN  NaN  NaN   NaN  0.000088  1.985400e-08  5.205800e-08
# 27657.685156  NaN  NaN  NaN   NaN  0.000088  1.992800e-08  5.218000e-08
# ...           ...  ...  ...   ...       ...           ...           ...
# 93407.882771  NaN  NaN  NaN   NaN  0.000083  1.505000e-08  4.557900e-08
# 93409.668311  NaN  NaN  NaN   NaN  0.000083  1.523500e-08  4.597900e-08
# 93411.448973  NaN  NaN  NaN   NaN  0.000083  1.514800e-08  4.463500e-08
# ...

# %% [markdown]
# We need to integrated the data(same scent name)!
# At first I'm not going to make the data length same(time)
# I'm simple going to cut by the minimum time length!

# %%
scent_list = []
current = 0
for scent_set_num in range(8):
    if scent_set_num == 2:
        step = 3
    else:
        step = 2
    scent_list.append(list(df_dict.keys())[current: current + step])
    current += step
print(scent_list)
# Out:
# [['1-heptanol', '1-heptanol_2'], ['2-ethylfenchol', '2-ethylfenchol_2'], ['decanal', 'decanal_2', 'decanal_3'], ['eugenol', 'eugenol_2'], ['octanal', 'octanal_2'], ['cis-3-hexenol', 'cis-3-hexenol_2'], ['2,3,5, trimethyl pyrazine', '2,3,5, trimethyl pyrazine_2'], ['geraniol', 'geraniol_2']]

# %%
scent_list
# Out:
# [['1-heptanol', '1-heptanol_2'],
#  ['2-ethylfenchol', '2-ethylfenchol_2'],
#  ['decanal', 'decanal_2', 'decanal_3'],
#  ['eugenol', 'eugenol_2'],
#  ['octanal', 'octanal_2'],
#  ['cis-3-hexenol', 'cis-3-hexenol_2'],
#  ['2,3,5, trimethyl pyrazine', '2,3,5, trimethyl pyrazine_2'],
#  ['geraniol', 'geraniol_2']]

# %% [markdown]
# ## The last trial generally has to many datas!
# Mostly beacause they give long time interval inorder to totally eliminate the leftover scent.
# ## And first trial gas too little datas!

# %%
# Making pattern
p = re.compile("([A-Za-z0-9, -]+)([\d_])*")

for scent_name in graph_df.index.map(lambda x: x[0]).unique():
    print(scent_name)
    last_trial_num = graph_df.loc[scent_name].index.map(lambda x: x[0]).max()
    first_trial_num = graph_df.loc[scent_name].index.map(lambda x: x[0]).min()
    graph_df = graph_df.drop([(scent_name, last_trial_num), (scent_name, first_trial_num)])
graph_df
# Out:
# 1-heptanol
# C:\Users\ansck\anaconda3\lib\site-packages\IPython\core\async_helpers.py:68: PerformanceWarning: indexing past lexsort depth may impact performance.
#   coro.send(None)
# 1-heptanol_2
# 2-ethylfenchol
# 2-ethylfenchol_2
# decanal
# decanal_2
# decanal_3
# eugenol
# eugenol_2
# octanal
# octanal_2
# cis-3-hexenol
# cis-3-hexenol_2
# 2,3,5, trimethyl pyrazine
# 2,3,5, trimethyl pyrazine_2
# geraniol
# geraniol_2
#                                             SAA           PAS           PVB  \
# scent_name trial_num Time (sec)
# 1-heptanol 1         600.681525    1.506200e-07  6.080700e-08  6.080700e-08
#                      601.758567    1.500970e-07  6.098600e-08  6.098600e-08
#                      602.825071    1.461190e-07  6.068800e-08  6.068800e-08
#                      603.936120    1.497220e-07  5.966700e-08  5.966700e-08
#                      605.037679    1.514290e-07  6.177500e-08  6.177500e-08
# ...

# %%
for scent_name in graph_df.index.map(lambda x: x[0]).unique():
    print(scent_name)
    for trial_num in graph_df.loc[scent_name].index.map(lambda x: x[0]).unique():
            print(f"trial num: {trial_num}, length: {len(graph_df.loc[(scent_name, trial_num)].index)}")
# Out:
# 1-heptanol
# C:\Users\ansck\anaconda3\lib\site-packages\ipykernel_launcher.py:4: PerformanceWarning: indexing past lexsort depth may impact performance.
#   after removing the cwd from sys.path.
# trial num: 1, length: 9122
# trial num: 2, length: 2538
# trial num: 3, length: 2518
# trial num: 4, length: 3362
# trial num: 5, length: 2553
# trial num: 6, length: 2492
# trial num: 7, length: 2483
# trial num: 8, length: 2492
# trial num: 9, length: 2490
# trial num: 10, length: 2481
# 1-heptanol_2
# trial num: 1, length: 1711
# trial num: 2, length: 1653
# trial num: 3, length: 1761
# trial num: 4, length: 1696
# trial num: 5, length: 1720
# trial num: 6, length: 1685
# trial num: 7, length: 1683
# trial num: 8, length: 1682
# trial num: 9, length: 1681
# 2-ethylfenchol
# trial num: 1, length: 2638
# trial num: 2, length: 2613
# trial num: 3, length: 2550
# trial num: 4, length: 2466
# trial num: 5, length: 2477
# trial num: 6, length: 2455
# trial num: 7, length: 2458
# ...

# %% [markdown]
# 1-heptanol trial_num 1 has too long time interval which leads to large data set comparing to others
# So let's ignore the trial number 1.

# %%
graph_df = graph_df.drop([("1-heptanol", 1)])
# Out:
# C:\Users\ansck\anaconda3\lib\site-packages\IPython\core\async_helpers.py:68: PerformanceWarning: indexing past lexsort depth may impact performance.
#   coro.send(None)

# %%
temp = []
for scent_name in graph_df.index.map(lambda x: x[0]).unique():
    print(scent_name)
    for trial_num in graph_df.loc[scent_name].index.map(lambda x: x[0]).unique():
        print(f"trial num: {trial_num}, length: {len(graph_df.loc[(scent_name, trial_num)].index)}")
        temp.append(len(graph_df.loc[(scent_name, trial_num)].index))
print(max(temp))
# Out:
# 1-heptanol
# trial num: 2, length: 2538
# trial num: 3, length: 2518
# trial num: 4, length: 3362
# trial num: 5, length: 2553
# trial num: 6, length: 2492
# trial num: 7, length: 2483
# trial num: 8, length: 2492
# trial num: 9, length: 2490
# trial num: 10, length: 2481
# 1-heptanol_2
# trial num: 1, length: 1711
# trial num: 2, length: 1653
# trial num: 3, length: 1761
# trial num: 4, length: 1696
# trial num: 5, length: 1720
# trial num: 6, length: 1685
# trial num: 7, length: 1683
# trial num: 8, length: 1682
# trial num: 9, length: 1681
# 2-ethylfenchol
# trial num: 1, length: 2638
# trial num: 2, length: 2613
# trial num: 3, length: 2550
# trial num: 4, length: 2466
# trial num: 5, length: 2477
# trial num: 6, length: 2455
# trial num: 7, length: 2458
# C:\Users\ansck\anaconda3\lib\site-packages\ipykernel_launcher.py:5: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """
# ...

# %% [markdown]
# We are going to make all the data in to length 3948!!!!
