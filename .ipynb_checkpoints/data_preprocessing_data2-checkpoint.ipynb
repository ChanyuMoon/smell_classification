# %%
import pandas as pd
import math
import re

# %%
data_url = "./data/단향 측정 데이터_김소희.xlsx"
df_dict = pd.read_excel(data_url, sheet_name=None)
print(df_dict)
# Out:
# {'1-heptanol':        Timestamps (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  \
# 0              0.000007  1.455080e-07  6.162300e-08  6.162300e-08
# 1              1.089014  1.512110e-07  6.103500e-08  6.103500e-08
# 2              2.241256  1.524380e-07  6.136400e-08  6.136400e-08
# 3              3.319816  1.522550e-07  6.101100e-08  6.101100e-08
# 4              4.403149  1.519720e-07  6.050100e-08  6.050100e-08
# ...                 ...           ...           ...           ...
# 35752      42317.146907  1.355400e-07  1.547080e-06  1.547080e-06
# 35753      42318.359245  1.370170e-07  1.543610e-06  1.543610e-06
# 35754      42319.545124  1.374300e-07  1.543960e-06  1.543960e-06
# 35755      42320.737173  1.371530e-07  1.544110e-06  1.544110e-06
# 35756      42321.878927  1.372520e-07  1.534830e-06  1.534830e-06
#
#        Ids (A)_PMMA  Unnamed: 5  gas injection time switch
# 0      3.536190e-07         NaN                 0.0    off
# ...

# %%
df_dict.keys()
# Out:
# dict_keys(['1-heptanol', '1-heptanol_2', '2-ethylfenchol', '2-ethylfenchol_2', 'decanal', 'decanal_2', 'decanal_3', 'eugenol', 'eugenol_2', 'octanal', 'octanal_2', 'cis-3-hexenol', 'cis-3-hexenol_2', '2,3,5, trimethyl pyrazine', '2,3,5, trimethyl pyrazine_2', 'geraniol', 'geraniol_2'])

# %% [markdown]
# ## Things to beaware of the data
# 1. the number of rows in each sensor aren't same(Even in the same scent!)

# %%
scent_list = []
current = 0
for scent_set_num in range(8):
    if scent_set_num == 2:
        step = 3
    else:
        step = 2
    scent_list.append(list(df_dict.keys())[current: current + step])
    current += step
# print(scent_list)
# Out:
#        Timestamps (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  \
# 0              0.000007  1.455080e-07  6.162300e-08  6.162300e-08
# 1              1.089014  1.512110e-07  6.103500e-08  6.103500e-08
# 2              2.241256  1.524380e-07  6.136400e-08  6.136400e-08
# 3              3.319816  1.522550e-07  6.101100e-08  6.101100e-08
# 4              4.403149  1.519720e-07  6.050100e-08  6.050100e-08
# ...                 ...           ...           ...           ...
# 35752      42317.146907  1.355400e-07  1.547080e-06  1.547080e-06
# 35753      42318.359245  1.370170e-07  1.543610e-06  1.543610e-06
# 35754      42319.545124  1.374300e-07  1.543960e-06  1.543960e-06
# 35755      42320.737173  1.371530e-07  1.544110e-06  1.544110e-06
# 35756      42321.878927  1.372520e-07  1.534830e-06  1.534830e-06
#
#        Ids (A)_PMMA  Unnamed: 5  gas injection time switch
# 0      3.536190e-07         NaN                 0.0    off
# ...

# %%
scent_list
# Out:
# [['1-heptanol', '1-heptanol_2'],
#  ['2-ethylfenchol', '2-ethylfenchol_2'],
#  ['decanal', 'decanal_2', 'decanal_3'],
#  ['eugenol', 'eugenol_2'],
#  ['octanal', 'octanal_2'],
#  ['cis-3-hexenol', 'cis-3-hexenol_2'],
#  ['2,3,5, trimethyl pyrazine', '2,3,5, trimethyl pyrazine_2'],
#  ['geraniol', 'geraniol_2']]

# %%
# Making pattern
p = re.compile("([A-Za-z0-9, -]+)([\d_])*")

for scent_set in scent_list:
    for key in scent_set:
        scent_name = p.match(key).group(1)
        scent_data = df_dict[key]
        options = scent_data.iloc[:, 6:8]
        options = options[options['gas injection time'].notnull()]
        scent_data = scent_data.iloc[:, :5]
        scent_data["scent_name"] = scent_name
#         print(f"scent_data: {scent_data}")
#         print(f"options: {options}")
        # making trials!!
        # we don't need 0!
        nose_open_close_pattern = list(options["gas injection time"])
        scent_data["trial_num"] = 0
        for i in range(len(nose_open_close_pattern)//2):
            scent_data["trial_num"] = scent_data.apply(lambda x: i + 1 if (nose_open_close_pattern[2*i] <= x["Timestamps (sec)"]) & (x["Timestamps (sec)"] < nose_open_close_pattern[2*i + 2]) else x["trial_num"] ,axis= 1)
        print(scent_data)
        print(scent_data[scent_data["trial_num"] == 3])
# Out:
#        Timestamps (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  \
# 0              0.000007  1.455080e-07  6.162300e-08  6.162300e-08
# 1              1.089014  1.512110e-07  6.103500e-08  6.103500e-08
# 2              2.241256  1.524380e-07  6.136400e-08  6.136400e-08
# 3              3.319816  1.522550e-07  6.101100e-08  6.101100e-08
# 4              4.403149  1.519720e-07  6.050100e-08  6.050100e-08
# ...                 ...           ...           ...           ...
# 35752      42317.146907  1.355400e-07  1.547080e-06  1.547080e-06
# 35753      42318.359245  1.370170e-07  1.543610e-06  1.543610e-06
# 35754      42319.545124  1.374300e-07  1.543960e-06  1.543960e-06
# 35755      42320.737173  1.371530e-07  1.544110e-06  1.544110e-06
# 35756      42321.878927  1.372520e-07  1.534830e-06  1.534830e-06
#
#        Ids (A)_PMMA  scent_name  trial_num
# 0      3.536190e-07  1-heptanol          1
# 1      3.527170e-07  1-heptanol          1
# ...

# %%
# GOALS : Make a on_off_state and Trial_numbers
# bubble is repeated by off/on.
# use math.inf to make a boundary for off in this case (+ 600, 1200)
nose_open_close_pattern = [600, 1200, 2400, 3000, 4200, 4800, 6000, 6600, 7800, 8400, 9600, 10200, 11400, 12000, 13200, 13800, 15000, 15600, 16800, 17400, 18600, 19200, math.inf]
# 1. "on_off_state"
#make a defalut column filled with "on"
integrated_data["on_off_state"] = "on"

for i in range(len(nose_open_close_pattern)//2):
    integrated_data["on_off_state"] = integrated_data.apply(lambda x: "off" if (nose_open_close_pattern[2*i] <= x["Time (sec)"]) & (x["Time (sec)"] < nose_open_close_pattern[2*i + 1]) else x["on_off_state"], axis=1)

# 2. "trial_num"
# set trial_num as 0 series.
integrated_data["trial_num"] = 0
for i in range(len(nose_open_close_pattern)//2):
    integrated_data["trial_num"] = integrated_data.apply(lambda x: i + 1 if (nose_open_close_pattern[2*i] <= x["Time (sec)"]) & (x["Time (sec)"] < nose_open_close_pattern[2*i + 2]) else x["trial_num"] ,axis= 1)

integrated_data.head()

# %%
first_scent_name = list(df_dict.keys())[0]
# Where we are going to integrate scent data in integrated data
# Make a "scent_name" column.
integrated_data = pd.DataFrame()
integrated_data["scent_name"] = None

# concat the df of each scent into integrated data.
for scent_name in df_dict.keys():
    df_dict[scent_name]["scent_name"] = scent_name
    integrated_data = pd.concat([integrated_data, df_dict[scent_name].iloc[:, :5]], ignore_index = True)  

print(integrated_data.head())
print(integrated_data.shape)
print(integrated_data["scent_name"].unique())
# Out:
#   scent_name  Timestamps (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  \
# 0        NaN          0.000007  1.455080e-07  6.162300e-08  6.162300e-08
# 1        NaN          1.089014  1.512110e-07  6.103500e-08  6.103500e-08
# 2        NaN          2.241256  1.524380e-07  6.136400e-08  6.136400e-08
# 3        NaN          3.319816  1.522550e-07  6.101100e-08  6.101100e-08
# 4        NaN          4.403149  1.519720e-07  6.050100e-08  6.050100e-08
#
#    Ids (A)_PMMA  Ids (A)_PVA  Ids (A)_PC  Ids (A)_PS  Ids (A)_PVCA  \
# 0  3.536190e-07          NaN         NaN         NaN           NaN
# 1  3.527170e-07          NaN         NaN         NaN           NaN
# 2  3.505370e-07          NaN         NaN         NaN           NaN
# 3  3.501920e-07          NaN         NaN         NaN           NaN
# 4  3.492120e-07          NaN         NaN         NaN           NaN
#
#    Ids (A)_PC.1
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# (347338, 11)
# ...

# %%
columns = df_dict[list(df_dict.keys())[0]].columns + df_dict[list(df_dict.keys())[1]].columns
columns

#  Where we are going to integrate scent data in integrated data
# Make a "scent_name" column.
# integrated_data = pd.DataFrame(columns= df_dict.keys())
# integrated_data["scent_name"] = None

# concat the df of each scent into integrated data.
# for scent_name in df_dict.keys():
#     df_dict[scent_name]["scent_name"] = scent_name
#     integrated_data = pd.concat([integrated_data, df_dict[scent_name]], ignore_index = True)  

# print(integrated_data.columns)
# print(integrated_data.shape)
# print(integrated_data["scent_name"].unique())
# Out:
# Index(['Timestamps (sec)Timestamps (sec)', 'Ids (A)_SAAIds (A)_PVA',
#        'Ids (A)_PASIds (A)_PC', 'Ids (A)_PVBIds (A)_PS',
#        'Ids (A)_PMMAIds (A)_PVCA', 'Unnamed: 5Unnamed: 5',
#        'gas injection timegas injection time', 'switchswitch',
#        'scent_namescent_name'],
#       dtype='object')

# %%
integrated_data.head()
# Out:
#   1-heptanol 1-heptanol_2 2-ethylfenchol 2-ethylfenchol_2 decanal decanal_2  \
# 0        NaN          NaN            NaN              NaN     NaN       NaN
# 1        NaN          NaN            NaN              NaN     NaN       NaN
# 2        NaN          NaN            NaN              NaN     NaN       NaN
# 3        NaN          NaN            NaN              NaN     NaN       NaN
# 4        NaN          NaN            NaN              NaN     NaN       NaN
#
#   decanal_3 eugenol eugenol_2 octanal  ...   Ids (A)_PVB  Ids (A)_PMMA  \
# 0       NaN     NaN       NaN     NaN  ...  6.162300e-08  3.536190e-07
# 1       NaN     NaN       NaN     NaN  ...  6.103500e-08  3.527170e-07
# 2       NaN     NaN       NaN     NaN  ...  6.136400e-08  3.505370e-07
# 3       NaN     NaN       NaN     NaN  ...  6.101100e-08  3.501920e-07
# 4       NaN     NaN       NaN     NaN  ...  6.050100e-08  3.492120e-07
#
#   Unnamed: 5 gas injection time switch Ids (A)_PVA Ids (A)_PC Ids (A)_PS  \
# ...

# %%
# Change Column name to "Time (sec)"
integrated_data = integrated_data.rename(columns = {"Timestamps (sec)" :"Time (sec)"})
integrated_data.head()
# Out:
#    Time (sec)   Ids (A)_SAA   Ids (A)_PAS   Ids (A)_PVB  Ids (A)_PMMA  \
# 0    0.000007  1.455080e-07  6.162300e-08  6.162300e-08  3.536190e-07
# 1    1.089014  1.512110e-07  6.103500e-08  6.103500e-08  3.527170e-07
# 2    2.241256  1.524380e-07  6.136400e-08  6.136400e-08  3.505370e-07
# 3    3.319816  1.522550e-07  6.101100e-08  6.101100e-08  3.501920e-07
# 4    4.403149  1.519720e-07  6.050100e-08  6.050100e-08  3.492120e-07
#
#    Unnamed: 5  gas injection time switch  scent_name  Ids (A)_PVA  Ids (A)_PC  \
# 0         NaN                 0.0    off  1-heptanol          NaN         NaN
# 1         NaN               600.0     on  1-heptanol          NaN         NaN
# 2         NaN              1200.0    off  1-heptanol          NaN         NaN
# 3         NaN             11000.0     on  1-heptanol          NaN         NaN
# 4         NaN             11600.0    off  1-heptanol          NaN         NaN
#
#    Ids (A)_PS  Ids (A)_PVCA  Ids (A)_PC.1
# ...

# %%
# bubble is repeated by off/on.
# use math.inf to make a boundary for off in this case (+ 600, 1200)
nose_open_close_pattern_A = [(0, 600), (1200, 2400), (3000, 4200), (4800, 6000), (6600, 7800), (8400, 9600), (10200, 11400), (12000, 13200), (13800, 15000), (15600, 16800), (17400, 18600), (19200, math.inf)]
nose_open_close_pattern_B = nose_open_close_pattern_A[:5] + [(8400, math.inf)]
# Heptanol is in A --> we are going to use nose_...A

#make a defalut column filled with "on"
integrated_data["on_off_state"] = "on"

pattern_A_scent = (integrated_data["scent_name"] =="Heptanol") | (integrated_data["scent_name"] == "2-ethylfenchol") | (integrated_data["scent_name"] == "Octanal")
# pattern_A_scent = integrated_data["scent_name"] in ["Heptanol", " 2-ethylfenchol", "Octanal"] --> why not working?

# print(integrated_data[pattern_A_scent].head())
# print(integrated_data[pattern_A_scent]["scent_name"].unique())

pattern_B_scent = (integrated_data["scent_name"] =="Eugenol") | (integrated_data["scent_name"] == "Cis-3-hexenol") | (integrated_data["scent_name"] == "Decanal") | (integrated_data["scent_name"] == "2,3,5 trymethylpyrazine") | (integrated_data["scent_name"] == "Geraniol")

# To prevent SettingWithCopyWarning error let's copy the view of the integrated_data.
A_view_of_integrated_data = integrated_data[pattern_A_scent].copy()

print(A_view_of_integrated_data)

for i, j in nose_open_close_pattern_A:
    A_view_of_integrated_data["on_off_state"] = A_view_of_integrated_data.apply(lambda x: "off" if (i <= x["Time (sec)"]) & (x["Time (sec)"] < j) else x["on_off_state"], axis=1)

print(A_view_of_integrated_data)

B_view_of_view_A_of_integrated_data = A_view_of_integrated_data[pattern_B_scent].copy()

print(B_view_of_view_A_of_integrated_data)

for i, j in nose_open_close_pattern_B:
    B_view_of_view_A_of_integrated_data["on_off_state"] = B_view_of_view_A_of_integrated_data.apply(lambda x: "off" if (i <= x["Time (sec)"]) & (x["Time (sec)"] < i) else x["on_off_state"], axis=1)

print(B_view_of_view_A_of_integrated_data)
# Out:
#         Time (sec)       ZnO (1)       ZnO (2)       ZnO (3)      SnO2 (1)  \
# 0         0.000009  7.740000e-10  3.028200e-07  1.332600e-08  7.239890e-05
# 1         2.981646  1.150800e-08  2.955960e-07  1.503100e-08  7.236550e-05
# 2         5.951279  1.164000e-08  2.985380e-07  1.300000e-08  7.296970e-05
# 3         8.889494  1.139700e-08  3.051830e-07  1.305800e-08  7.315950e-05
# 4        11.895487  8.972000e-09  2.375300e-07  7.302000e-09  7.316050e-05
# ...            ...           ...           ...           ...           ...
# 36665  9874.223003  9.247000e-09  1.594300e-08  7.580000e-09  1.808820e-07
# 36666  9877.246378  9.823000e-09  1.661600e-08  7.899000e-09  1.823760e-07
# 36667  9880.249852  1.018300e-08  1.642700e-08  7.808000e-09  1.802410e-07
# 36668  9883.257690  1.040500e-08  1.850600e-08  8.139000e-09  1.867930e-07
# 36669  9886.271773  1.004100e-08  1.622500e-08  7.898000e-09  1.832770e-07
#
# ...

# %% [markdown]
# Like about the error of view of DataFrame in pandas
# : https://emilkwak.github.io/pandas-dataframe-settingwithcopywarning
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
