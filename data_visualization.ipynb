# %% [markdown]
# # Visualization of preprocessed data
# Going to look at the data it self.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
scent_data = pd.read_pickle("./data/preprocessed_data.pkl")
scent_data.head()
# Out:
#                                                        ZnO                \
#                                                          1             2
# scent_name trial_num on_off_state Time (sec)
# Heptanol   0         on           0.000009    7.740000e-10  3.028200e-07
#                                   2.981646    1.150800e-08  2.955960e-07
#                                   5.951279    1.164000e-08  2.985380e-07
#                                   8.889494    1.139700e-08  3.051830e-07
#                                   11.895487   8.972000e-09  2.375300e-07
#
#                                                                 SnO2  \
#                                                          3         1
# scent_name trial_num on_off_state Time (sec)
# Heptanol   0         on           0.000009    1.332600e-08  0.000072
#                                   2.981646    1.503100e-08  0.000072
#                                   5.951279    1.300000e-08  0.000073
# ...

# %%
scent_data.shape
# Out:
# (36670, 9)

# %%
scent_data.columns
# Out:
# MultiIndex([( 'ZnO', 1),
#             ( 'ZnO', 2),
#             ( 'ZnO', 3),
#             ('SnO2', 1),
#             ('SnO2', 2),
#             ('SnO2', 3),
#             ( 'AZO', 1),
#             ( 'AZO', 2),
#             ( 'AZO', 3)],
#            )

# %% [markdown]
# ## scent sensors
# There are no difference on the ZnO(1), ZnO(2),..
# And also the data was measured using 9 sensors at the single trials.
# And also this data needs to be visualized using time axis.

# %%
# To learn more about multi-indexing go look multi-index.txt
scent_data.loc["Heptanol", 1, :]
# Out:
#                                    ZnO                                  SnO2  \
#                                      1             2             3         1
# on_off_state Time (sec)
# off          602.290883   1.184100e-08  4.729630e-07  2.050200e-08  0.000075
#              605.298575   1.066900e-08  4.498490e-07  1.905700e-08  0.000075
#              608.322897   1.154800e-08  4.881370e-07  1.891100e-08  0.000075
#              611.334691   1.160100e-08  4.059930e-07  1.919600e-08  0.000075
#              614.342759   1.175700e-08  4.858830e-07  1.987100e-08  0.000075
# ...                                ...           ...           ...       ...
# on           2385.566313  1.105800e-08  5.901580e-07  2.060600e-08  0.000081
#              2388.578338  1.060500e-08  6.285200e-07  1.901200e-08  0.000081
#              2391.519402  1.486000e-08  5.700500e-07  1.771800e-08  0.000081
#              2394.500439  1.151400e-08  6.285400e-07  2.444700e-08  0.000081
# ...

# %%
# This is how to drop the middle level index at the multi-index structure.
scent_data_plot = scent_data.droplevel("on_off_state")
scent_data_plot.head()
# Out:
#                                           ZnO                              \
#                                             1             2             3
# scent_name trial_num Time (sec)
# Heptanol   0         0.000009    7.740000e-10  3.028200e-07  1.332600e-08
#                      2.981646    1.150800e-08  2.955960e-07  1.503100e-08
#                      5.951279    1.164000e-08  2.985380e-07  1.300000e-08
#                      8.889494    1.139700e-08  3.051830e-07  1.305800e-08
#                      11.895487   8.972000e-09  2.375300e-07  7.302000e-09
#
#                                      SnO2                               AZO  \
#                                         1         2         3             1
# scent_name trial_num Time (sec)
# Heptanol   0         0.000009    0.000072  0.000065  0.000053  1.267340e-07
#                      2.981646    0.000072  0.000064  0.000054  1.277770e-07
#                      5.951279    0.000073  0.000065  0.000054  1.306230e-07
# ...

# %%
scent_data_plot.droplevel("trial_num").loc["Heptanol","ZnO"]
# Out:
#                          1             2             3
# Time (sec)
# 0.000009      7.740000e-10  3.028200e-07  1.332600e-08
# 2.981646      1.150800e-08  2.955960e-07  1.503100e-08
# 5.951279      1.164000e-08  2.985380e-07  1.300000e-08
# 8.889494      1.139700e-08  3.051830e-07  1.305800e-08
# 11.895487     8.972000e-09  2.375300e-07  7.302000e-09
# ...                    ...           ...           ...
# 20811.378324  1.416000e-08  2.425700e-07  1.559200e-08
# 20814.387244  1.684000e-08  2.796200e-07  1.222800e-08
# 20817.388022  1.315500e-08  2.147550e-07  2.374100e-08
# 20820.404342  1.562500e-08  2.394680e-07  7.314000e-09
# 20823.416638  1.898300e-08           NaN           NaN
#
# [6873 rows x 3 columns]

# %% [markdown]
# ## First let's look at the whole current-time graph of Heptanol

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Heptanol","ZnO"])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.loc[("Heptanol", 1), ("SnO2", 1)])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()
# Out:
# C:\Users\ansck\anaconda3\lib\site-packages\pandas\core\indexing.py:1761: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Heptanol","SnO2"])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Heptanol","AZO"])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %% [markdown]
# ## Now let's look at the other data from scent.

# %%
fig, axes = plt.subplots(8, 3)
fig.set_size_inches((20,5))

# %%
scent_data_plot.columns
# Out:
# MultiIndex([( 'ZnO', 1),
#             ( 'ZnO', 2),
#             ( 'ZnO', 3),
#             ('SnO2', 1),
#             ('SnO2', 2),
#             ('SnO2', 3),
#             ( 'AZO', 1),
#             ( 'AZO', 2),
#             ( 'AZO', 3)],
#            )

# %%
row = 0
for scent in scent_data_plot.index.map(lambda x: x[0]).unique():
    column = 0
    for sensor in scent_data_plot.columns.map(lambda x: x[0]).unique():
        axes[row][column].plot(scent_data_plot.droplevel("trial_num").loc[scent, sensor])
        column += 1
    row += 1

fig

# %% [markdown]
# ## But there are some strange datas

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Heptanol",("ZnO", 1)])
# plt.plot(scent_data_plot.droplevel("trial_num").loc["Heptanol",("ZnO", 3)])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Heptanol",("ZnO", 2)])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Heptanol",("ZnO", 3)])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Geraniol",("AZO", 1)][700:])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Geraniol",("AZO", 2)][700:])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %%
# plt.plot(scent_data_plot.loc["Heptanol", :]["ZnO"])
plt.plot(scent_data_plot.droplevel("trial_num").loc["Geraniol",("AZO", 3)][700:])

plt.rcParams["figure.figsize"] = (25,4)
plt.show()

# %% [markdown]
# ## To small so let's make 3 of them

# %%
scent_data_plot.index.map(lambda x: x[0]).unique()
# Out:
# Index(['Heptanol', '2-ethylfenchol', 'Octanal', 'Eugenol', 'Cis-3-hexenol',
#        'Decanal', '2,3,5 trymethylpyrazine', 'Geraniol'],
#       dtype='object')

# %%
fig, axes = plt.subplots(24, 1, constrained_layout= True)
fig.set_size_inches((20,40))

num = 0
for scent in scent_data_plot.index.map(lambda x: x[0]).unique():
    for sensor in scent_data_plot.columns.map(lambda x: x[0]).unique():
        axes[num].plot(scent_data_plot.droplevel("trial_num").loc[scent, sensor])
        axes[num].set_title(f"{scent}: {sensor}")
        num += 1
